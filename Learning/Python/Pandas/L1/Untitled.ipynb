# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "Name" : ["Taha", "Owais", "Saim"],
    "Marks" : [90, 79, 89]
})

# %%
df
# Out:
#     Name  Marks
# 0   Taha     90
# 1  Owais     79
# 2   Saim     89

# %%
df = pd.read_excel("dataset/All IL Zip Code 1.xls")
df
# Out:
#                                                     zip  Zipcode name  \
# 0                                                 61410  ABINGDON, IL
# 1                                                   NaN     ADAIR, IL
# 2                                                 62214           NaN
# 3                                                 60101   ADDISON, IL
# 4                                                 61230    ALBANY, IL
# ...                                                 ...           ...
# 1506                                              62999   ZEIGLER, IL
# 1507                                              60099      ZION, IL
# 1508                                                NaN           NaN
# 1509                                                NaN           NaN
# 1510  For more information, kindly visit: www.downlo...           NaN
#
#             City State County Name
# 0       ABINGDON    IL         NaN
# 1            NaN    IL   MCDONOUGH
# ...

# %%
df.head()
# Out:
#      zip  Zipcode name        City State County Name
# 0  61410  ABINGDON, IL    ABINGDON    IL         NaN
# 1    NaN     ADAIR, IL         NaN    IL   MCDONOUGH
# 2  62214           NaN  ADDIEVILLE    IL  WASHINGTON
# 3  60101   ADDISON, IL         NaN    IL      DUPAGE
# 4  61230    ALBANY, IL      ALBANY   NaN   WHITESIDE

# %%
df.dropna()
# Out:
#         zip    Zipcode name        City State County Name
# 5     62215      ALBERS, IL      ALBERS    IL     CLINTON
# 7     60001       ALDEN, IL       ALDEN    IL     MCHENRY
# 8     61231       ALEDO, IL       ALEDO    IL      MERCER
# 9     62601   ALEXANDER, IL   ALEXANDER    IL      MORGAN
# 10    61412      ALEXIS, IL      ALEXIS    IL      MERCER
# ...     ...             ...         ...   ...         ...
# 1503  62481        YALE, IL        YALE    IL      JASPER
# 1504  61572  YATES CITY, IL  YATES CITY    IL        KNOX
# 1505  60560   YORKVILLE, IL   YORKVILLE    IL     KENDALL
# 1506  62999     ZEIGLER, IL     ZEIGLER    IL    FRANKLIN
# 1507  60099        ZION, IL        ZION    IL        LAKE
#
# [1502 rows x 5 columns]

# %%
df.fillna(0)
# Out:
#                                                     zip  Zipcode name  \
# 0                                                 61410  ABINGDON, IL
# 1                                                     0     ADAIR, IL
# 2                                                 62214             0
# 3                                                 60101   ADDISON, IL
# 4                                                 61230    ALBANY, IL
# ...                                                 ...           ...
# 1506                                              62999   ZEIGLER, IL
# 1507                                              60099      ZION, IL
# 1508                                                  0             0
# 1509                                                  0             0
# 1510  For more information, kindly visit: www.downlo...             0
#
#             City State County Name
# 0       ABINGDON    IL           0
# 1              0    IL   MCDONOUGH
# ...

# %%
df[["zip", "City"]]
# Out:
#                                                     zip        City
# 0                                                 61410    ABINGDON
# 1                                                   NaN         NaN
# 2                                                 62214  ADDIEVILLE
# 3                                                 60101         NaN
# 4                                                 61230      ALBANY
# ...                                                 ...         ...
# 1506                                              62999     ZEIGLER
# 1507                                              60099        ZION
# 1508                                                NaN         NaN
# 1509                                                NaN         NaN
# 1510  For more information, kindly visit: www.downlo...         NaN
#
# [1511 rows x 2 columns]

# %%
df.rename(columns={"City": "Cities"})
# Out:
#                                                     zip  Zipcode name  \
# 0                                                 61410  ABINGDON, IL
# 1                                                   NaN     ADAIR, IL
# 2                                                 62214           NaN
# 3                                                 60101   ADDISON, IL
# 4                                                 61230    ALBANY, IL
# ...                                                 ...           ...
# 1506                                              62999   ZEIGLER, IL
# 1507                                              60099      ZION, IL
# 1508                                                NaN           NaN
# 1509                                                NaN           NaN
# 1510  For more information, kindly visit: www.downlo...           NaN
#
#           Cities State County Name
# 0       ABINGDON    IL         NaN
# 1            NaN    IL   MCDONOUGH
# ...

# %%
df
# Out:
#                                                     zip  Zipcode name  \
# 0                                                 61410  ABINGDON, IL
# 1                                                   NaN     ADAIR, IL
# 2                                                 62214           NaN
# 3                                                 60101   ADDISON, IL
# 4                                                 61230    ALBANY, IL
# ...                                                 ...           ...
# 1506                                              62999   ZEIGLER, IL
# 1507                                              60099      ZION, IL
# 1508                                                NaN           NaN
# 1509                                                NaN           NaN
# 1510  For more information, kindly visit: www.downlo...           NaN
#
#             City State County Name
# 0       ABINGDON    IL         NaN
# 1            NaN    IL   MCDONOUGH
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1511 entries, 0 to 1510
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   zip           1508 non-null   object
#  1   Zipcode name  1507 non-null   object
#  2   City          1506 non-null   object
#  3   State         1507 non-null   object
#  4   County Name   1506 non-null   object
# dtypes: object(5)
# memory usage: 59.2+ KB

# %%
df = df.dropna(subset=["zip"])
df['zip'] = df['zip'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 2
#       1 df = df.dropna(subset=["zip"])
# ----> 2 df['zip'] = df['zip'].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# ...

# %%
len(df)
# Out:
# 1508

# %%
df
# Out:
#                                                     zip    Zipcode name  \
# 0                                                 61410    ABINGDON, IL
# 2                                                 62214             NaN
# 3                                                 60101     ADDISON, IL
# 4                                                 61230      ALBANY, IL
# 5                                                 62215      ALBERS, IL
# ...                                                 ...             ...
# 1504                                              61572  YATES CITY, IL
# 1505                                              60560   YORKVILLE, IL
# 1506                                              62999     ZEIGLER, IL
# 1507                                              60099        ZION, IL
# 1510  For more information, kindly visit: www.downlo...             NaN
#
#             City State County Name
# 0       ABINGDON    IL         NaN
# ...

# %%
#df["Status"] = [0 for i in range (len(df))]
df["NewColumn"] = "Active"
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_2436\2430101248.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["NewColumn"] = "Active"
