# %%
pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in c:\users\hp\anaconda3\lib\site-packages (5.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
df = pd.read_csv('netflix_titles.csv')

# %%
import sqlalchemy as sal
engine = sal.create_engine('mssql+pyodbc://DESKTOP-O4QNJ9S\SQLEXPRESS/master?driver=ODBC+Driver+18+for+SQL+Server&trusted_connection=yes&Encrypt=no')
conn=engine.connect()

# %%
df.to_sql('netflix_raw', con=conn , index=False, if_exists = 'append')
conn.close()

# %%
len(df)
# Out:
# 8807

# %%
df[df.show_id=='s5023']
# Out:
#      show_id   type    title       director           cast      country  \
# 5022   s5023  Movie  반드시 잡는다  Hong-seon Kim  Baek Yoon-sik  South Korea
#
#              date_added  release_year rating duration  \
# 5022  February 28, 2018          2017  TV-MA  110 min
#
#                                     listed_in  \
# 5022  Dramas, International Movies, Thrillers
#
#                                             description
# 5022  After people in his town start turning up dead...

# %%
df.show_id.str.len()
# Out:
# 0       2
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 8802    5
# 8803    5
# 8804    5
# 8805    5
# 8806    5
# Name: show_id, Length: 8807, dtype: int64

# %%
df.head()
df[df.show_id=='s5023']
max(df.description.dropna().str.len())
df.isna().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64
