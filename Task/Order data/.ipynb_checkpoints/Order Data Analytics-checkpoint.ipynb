# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
# read data and  handle missind values of ship mode column 
df=pd.read_csv ('orders.csv',na_values = [ 'Not Available', 'unknown'])
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1    3/1/2023    Second Class   Consumer  United States
# 1            2   8/15/2023    Second Class   Consumer  United States
# 2            3   1/10/2023    Second Class  Corporate  United States
# 3            4   6/18/2022  Standard Class   Consumer  United States
# 4            5   7/13/2022  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990   2/18/2023    Second Class   Consumer  United States
# 9990      9991   3/17/2023  Standard Class   Consumer  United States
# 9991      9992    8/7/2022  Standard Class   Consumer  United States
# 9992      9993  11/19/2022  Standard Class   Consumer  United States
# 9993      9994   7/17/2022    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# ...

# %%
df.head()
# Out:
#    Order Id Order Date       Ship Mode    Segment        Country  \
# 0         1   3/1/2023    Second Class   Consumer  United States
# 1         2  8/15/2023    Second Class   Consumer  United States
# 2         3  1/10/2023    Second Class  Corporate  United States
# 3         4  6/18/2022  Standard Class   Consumer  United States
# 4         5  7/13/2022  Standard Class   Consumer  United States
#
#               City       State  Postal Code Region         Category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# 2      Los Angeles  California        90036   West  Office Supplies
# 3  Fort Lauderdale     Florida        33311  South        Furniture
# 4  Fort Lauderdale     Florida        33311  South  Office Supplies
#
#   Sub Category       Product Id  cost price  List Price  Quantity  \
# 0    Bookcases  FUR-BO-10001798         240         260         2
# ...

# %%
df['Ship Mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', nan, 'First Class', 'Same Day'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Order Id', 'Order Date', 'Ship Mode', 'Segment', 'Country', 'City',
#        'State', 'Postal Code', 'Region', 'Category', 'Sub Category',
#        'Product Id', 'cost price', 'List Price', 'Quantity',
#        'Discount Percent'],
#       dtype='object')

# %%
#rename column name 
df.columns=df.columns.str.lower()
df.columns= df.columns.str.replace (' ','_')

# %%
df.head(10)
# Out:
#    order_id  order_date       ship_mode    segment        country  \
# 0         1    3/1/2023    Second Class   Consumer  United States
# 1         2   8/15/2023    Second Class   Consumer  United States
# 2         3   1/10/2023    Second Class  Corporate  United States
# 3         4   6/18/2022  Standard Class   Consumer  United States
# 4         5   7/13/2022  Standard Class   Consumer  United States
# 5         6   3/13/2022             NaN   Consumer  United States
# 6         7  12/28/2022  Standard Class   Consumer  United States
# 7         8   1/25/2022  Standard Class   Consumer  United States
# 8         9   3/23/2023             NaN   Consumer  United States
# 9        10   5/16/2023  Standard Class   Consumer  United States
#
#               city       state  postal_code region         category  \
# 0        Henderson    Kentucky        42420  South        Furniture
# 1        Henderson    Kentucky        42420  South        Furniture
# ...

# %%
# derive new column discount,sale_price and profit
df['discount']=df['list_price']*df['discount_percent']*.01

# %%
df['discount']
# Out:
# 0        5.2
# 1       21.9
# 2        0.5
# 3       19.2
# 4        1.0
#         ...
# 9989     1.2
# 9990     3.6
# 9991     5.2
# 9992     0.9
# 9993     7.2
# Name: discount, Length: 9994, dtype: float64

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1    3/1/2023    Second Class   Consumer  United States
# 1            2   8/15/2023    Second Class   Consumer  United States
# 2            3   1/10/2023    Second Class  Corporate  United States
# 3            4   6/18/2022  Standard Class   Consumer  United States
# 4            5   7/13/2022  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990   2/18/2023    Second Class   Consumer  United States
# 9990      9991   3/17/2023  Standard Class   Consumer  United States
# 9991      9992    8/7/2022  Standard Class   Consumer  United States
# 9992      9993  11/19/2022  Standard Class   Consumer  United States
# 9993      9994   7/17/2022    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['sale_price']=df['list_price']-df['discount']

# %%
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1    3/1/2023    Second Class   Consumer  United States
# 1            2   8/15/2023    Second Class   Consumer  United States
# 2            3   1/10/2023    Second Class  Corporate  United States
# 3            4   6/18/2022  Standard Class   Consumer  United States
# 4            5   7/13/2022  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990   2/18/2023    Second Class   Consumer  United States
# 9990      9991   3/17/2023  Standard Class   Consumer  United States
# 9991      9992    8/7/2022  Standard Class   Consumer  United States
# 9992      9993  11/19/2022  Standard Class   Consumer  United States
# 9993      9994   7/17/2022    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
df['profit']=df['sale_price']-df['cost_price']
df
# Out:
#       order_id  order_date       ship_mode    segment        country  \
# 0            1    3/1/2023    Second Class   Consumer  United States
# 1            2   8/15/2023    Second Class   Consumer  United States
# 2            3   1/10/2023    Second Class  Corporate  United States
# 3            4   6/18/2022  Standard Class   Consumer  United States
# 4            5   7/13/2022  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990   2/18/2023    Second Class   Consumer  United States
# 9990      9991   3/17/2023  Standard Class   Consumer  United States
# 9991      9992    8/7/2022  Standard Class   Consumer  United States
# 9992      9993  11/19/2022  Standard Class   Consumer  United States
# 9993      9994   7/17/2022    Second Class   Consumer  United States
#
#                  city       state  postal_code region         category  \
# ...

# %%
#convert order date from object data type tp datetime
# df['order_date'] = pd.to_datetime(df['order_date'], format="%Y-%m-%d")
# df.dtypes

df['order_date'] = pd.to_datetime(
    df['order_date'],
    dayfirst=True,
    errors='coerce'
)
df.dtypes
# Out:
# order_id                 int64
# order_date      datetime64[ns]
# ship_mode               object
# segment                 object
# country                 object
# city                    object
# state                   object
# postal_code              int64
# region                  object
# category                object
# sub_category            object
# product_id              object
# quantity                 int64
# discount               float64
# sale_price             float64
# profit                 float64
# dtype: object

# %%
#drop cost price list price and discount percent columns
df.drop(columns=['list_price', 'cost_price', 'discount_percent'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 4
#       1 #drop cost price list price and discount percent columns
#       2 # df.drop(columns=['list_price', 'cost_price', 'discount_percent'], inplace=True)
# ----> 4 df.drop(
#       5     columns=['list_price', 'cost_price', 'discount_percent'],
#       6     inplace=True
#       7 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
# ...

# %%
df.columns

# %%
df.to_sql(
    'df_orders',
    conn=engine,
    if_exists='replace',
    index=False
)

# %%
#load the data into sql server using replace option
import sqlalchemy as sal
engine = sal.create_engine('mssql://DESKTOP-O4QNJ9S\SQLEXPRESS/master?driver=ODBC+DRIVER+17+FOR+SQL+SERVER')
conn=engine.connect()
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:146, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     145 try:
# --> 146     self._dbapi_connection = engine.raw_connection()
#     147 except dialect.loaded_dbapi.Error as err:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:3298, in Engine.raw_connection(self)
#    3277 """Return a "raw" DBAPI connection from the connection pool.
#    3278
#    3279 The returned object is a proxied version of the DBAPI
#    (...)
#    3296
#    3297 """
# -> 3298 return self.pool.connect()
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\pool\base.py:449, in Pool.connect(self)
#     442 """Return a DBAPI connection from the pool.
#     443
#     444 The connection is instrumented such that when its
#    (...)
# ...

# %%
#load the data into sql server using append option
df.to_sql('df_orders', con=conn , index=False, if_exists = 'append')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 #load the data into sql server using append option
# ----> 2 df.to_sql('df_orders', con=conn , index=False, if_exists = 'append')
#
# NameError: name 'conn' is not defined
